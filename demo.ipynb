# %%
from pathlib import Path

import pandas as pd

titanic_df = pd.read_csv(Path().joinpath('data', 'titanic.csv'))
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
sample_titanic=titanic_df.sample(10)

# %%
sum_null=titanic_df.isnull().sum()

# %%
import seaborn as sns
from matplotlib import pyplot as plt


def count_plot(x, hue, data):
    sns.countplot(x=x, hue=hue, data=data)
    plt.show()


count_plot('Survived','Sex',titanic_df)

# %%
count_plot('Survived','Pclass',titanic_df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-5f1da47545d6> in <module>
# ----> 1 count_plot('Survived','Pclass',titanic_df)
#
# <ipython-input-8-162d76466803> in count_plot(x, hue, data)
#       5 def count_plot(x, hue, data):
#       6     sns.countplot(x=x, hue=hue, data=data)
# ----> 7     plt.show()
#       8
#       9
#
# ~\Miniconda3\envs\pycharm_webinar\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~\Miniconda3\envs\pycharm_webinar\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ...

# %%
import sqlite3
conn = sqlite3.connect(str(Path().joinpath('data','chinook.sqlite')))

pd.read_sql('SELECT Album.Title, T.Name FROM Album JOIN Track T on Album.AlbumId = T.AlbumId LIMIT 5', conn)

# %% [markdown]
# HERE!
